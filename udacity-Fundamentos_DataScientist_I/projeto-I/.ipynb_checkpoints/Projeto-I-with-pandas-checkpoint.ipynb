# %% [markdown]
# # Projeto I - Pandas
#
# Este Jupyter Notebooke tem por objetivo realizar testes em Datasets utilizando a biblioteca **pandas**. Realizando testes de maneira autônoma, pretende-se analisar o Dataset utilizado no projeto 1 para familiarização com a biblioteca.

# %%
# Importanto bibliotecas
import pandas as pd

# %%
path = 'C:/Users/thiagoPanini/Downloads/chicago.csv'
df_bike = pd.read_csv(path)
df_bike.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-01-01 00:00:36  2017-01-01 00:06:32            356
# 1  2017-01-01 00:02:54  2017-01-01 00:08:21            327
# 2  2017-01-01 00:06:06  2017-01-01 00:18:31            745
# 3  2017-01-01 00:07:28  2017-01-01 00:12:51            323
# 4  2017-01-01 00:07:57  2017-01-01 00:20:53            776
#
#                           Start Station                   End Station  \
# 0                  Canal St & Taylor St      Canal St & Monroe St (*)
# 1            Larrabee St & Menomonee St  Sheffield Ave & Kingsbury St
# 2  Orleans St & Chestnut St (NEXT Apts)    Ashland Ave & Blackhawk St
# 3               Franklin St & Monroe St        Clinton St & Tilden St
# 4                  Broadway & Barry Ave       Sedgwick St & North Ave
#
#     User Type Gender  Birth Year
# 0    Customer    NaN         NaN
# 1  Subscriber   Male      1984.0
# 2  Subscriber   Male      1985.0
# 3  Subscriber   Male      1990.0
# 4  Subscriber   Male      1990.0

# %%
# Verificando a quantidade de linhas e colunas do DataFrame
df_bike.shape
# Out:
# (1551505, 8)

# %%
# Verificando o tipo de dado de cada coluna
df_bike.dtypes
# Out:
# Start Time        object
# End Time          object
# Trip Duration      int64
# Start Station     object
# End Station       object
# User Type         object
# Gender            object
# Birth Year       float64
# dtype: object

# %%
# Muitas vezes, colunas do tipo str são mostradas como object. Vamos analisar a primeira linha da coluna Start Time

df_bike['Start Time'][0]
# Out:
# '2017-01-01 00:00:36'

# %%
# Verificando o tipo primitivo de cada uma das colunas identificadas como "object"

print(f"Tipo da coluna 'Start Time': {type(df_bike['Start Time'][0])}")
print(f"Tipo da coluna 'End Time': {type(df_bike['End Time'][0])}")
print(f"Tipo da coluna 'Start Duration': {type(df_bike['Start Station'][0])}")
print(f"Tipo da coluna 'End Station': {type(df_bike['End Station'][0])}")
print(f"Tipo da coluna 'User Type': {type(df_bike['User Type'][0])}")
print(f"Tipo da coluna 'Gender': {type(df_bike['Gender'][0])}")
# Out:
# Tipo da coluna 'Start Time': <class 'str'>
# Tipo da coluna 'End Time': <class 'str'>
# Tipo da coluna 'Start Duration': <class 'str'>
# Tipo da coluna 'End Station': <class 'str'>
# Tipo da coluna 'User Type': <class 'str'>
# Tipo da coluna 'Gender': <class 'float'>

# %%
# Verificando o tipo do dataset lido com pandas
type(df_bike)
# Out:
# pandas.core.frame.DataFrame

# %%
# Verificando todas as informações possíveis do dataset
df_bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1551505 entries, 0 to 1551504
# Data columns (total 8 columns):
# Start Time       1551505 non-null object
# End Time         1551505 non-null object
# Trip Duration    1551505 non-null int64
# Start Station    1551505 non-null object
# End Station      1551505 non-null object
# User Type        1551505 non-null object
# Gender           1234638 non-null object
# Birth Year       1234822 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 94.7+ MB

# %% [markdown]
# O método info() mostrado acima indica que há colunas com dados nulos, como é o caso de 'Gender' e 'Birth Year'. Isto pois a contagem total de linhas (1.551.505) é menor nestes dois atributos, o que indica que houve entradas de dados nulas.

# %%
# Verificando a quantidade de entradas únicas em cada coluna
df_bike.nunique()
# Out:
# Start Time       1374908
# End Time         1338926
# Trip Duration      12096
# Start Station        582
# End Station          581
# User Type              3
# Gender                 2
# Birth Year            82
# dtype: int64

# %% [markdown]
# O método nunique() indica a quantidade de entradas possíveis para cada valor. Entretanto, a informação mostrada não considera entradas nulas (verificar que 'Gender' é mostrado com 2 entradas possíveis, entretanto há 3 se considerar a entrada nula).

# %%
# Mostrando estatísticas descritivas sobre cada coluna do dataset
df_bike.describe()
# Out:
#        Trip Duration    Birth Year
# count   1.551505e+06  1.234822e+06
# mean    9.397778e+02  1.980864e+03
# std     1.617702e+03  1.099154e+01
# min     6.000000e+01  1.899000e+03
# 25%     3.920000e+02  1.975000e+03
# 50%     6.700000e+02  1.984000e+03
# 75%     1.127000e+03  1.989000e+03
# max     8.633800e+04  2.016000e+03

# %% [markdown]
# Perceba que o método describe() avalia apenas colunas cujo tipo primitivo é dado como numérico.

# %%
# Visualizando todas as colunas do dataset em formato de lista
df_bike.columns
# Out:
# Index(['Start Time', 'End Time', 'Trip Duration', 'Start Station',
#        'End Station', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')

# %%
for column in df_bike.columns:
    print(column)
# Out:
# Start Time
# End Time
# Trip Duration
# Start Station
# End Station
# User Type
# Gender
# Birth Year

# %%
for i, v in enumerate(df_bike.columns):
    print(i, v)
# Out:
# 0 Start Time
# 1 End Time
# 2 Trip Duration
# 3 Start Station
# 4 End Station
# 5 User Type
# 6 Gender
# 7 Birth Year

# %% [markdown]
# ## Selecionando e Indexando Datasets com .loc e .iloc
# Para melhor entendimento das inúmeras possibilidades com essas duas funções, é recomendada a leitura do seguinte link:
#
# [Selecting-and-indexing-with-loc-iloc](https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/)

# %% [markdown]
# ![Pandas-selections-and-indexing.png](attachment:Pandas-selections-and-indexing.png)

# %% [markdown]
# ## .loc
# Indexando através do nome (label) da coluna do Dataset.

# %%
# Verificando Dataset
df_bike.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-01-01 00:00:36  2017-01-01 00:06:32            356
# 1  2017-01-01 00:02:54  2017-01-01 00:08:21            327
# 2  2017-01-01 00:06:06  2017-01-01 00:18:31            745
# 3  2017-01-01 00:07:28  2017-01-01 00:12:51            323
# 4  2017-01-01 00:07:57  2017-01-01 00:20:53            776
#
#                           Start Station                   End Station Gender  \
# 0                  Canal St & Taylor St      Canal St & Monroe St (*)    NaN
# 1            Larrabee St & Menomonee St  Sheffield Ave & Kingsbury St   Male
# 2  Orleans St & Chestnut St (NEXT Apts)    Ashland Ave & Blackhawk St   Male
# 3               Franklin St & Monroe St        Clinton St & Tilden St   Male
# 4                  Broadway & Barry Ave       Sedgwick St & North Ave   Male
#
#    Birth Year
# 0         NaN
# 1      1984.0
# 2      1985.0
# 3      1990.0
# 4      1990.0

# %%
for i, v in enumerate(df_bike.columns):
    print(i, v)
# Out:
# 0 Start Time
# 1 End Time
# 2 Trip Duration
# 3 Start Station
# 4 End Station
# 5 Gender
# 6 Birth Year

# %%
# Selecionando todos os dados entre Trip Duration e User Type
df_teste = df_bike.loc[:,'Trip Duration':'User Type']
df_teste.head()
# Out:
#    Trip Duration                         Start Station  \
# 0            356                  Canal St & Taylor St
# 1            327            Larrabee St & Menomonee St
# 2            745  Orleans St & Chestnut St (NEXT Apts)
# 3            323               Franklin St & Monroe St
# 4            776                  Broadway & Barry Ave
#
#                     End Station   User Type
# 0      Canal St & Monroe St (*)    Customer
# 1  Sheffield Ave & Kingsbury St  Subscriber
# 2    Ashland Ave & Blackhawk St  Subscriber
# 3        Clinton St & Tilden St  Subscriber
# 4       Sedgwick St & North Ave  Subscriber

# %%
# Selecionando apenas Start Station e Start Time
df_teste = df_bike.loc[:, ['Start Station', 'Start Time']]
df_teste.head()
# Out:
#                           Start Station           Start Time
# 0                  Canal St & Taylor St  2017-01-01 00:00:36
# 1            Larrabee St & Menomonee St  2017-01-01 00:02:54
# 2  Orleans St & Chestnut St (NEXT Apts)  2017-01-01 00:06:06
# 3               Franklin St & Monroe St  2017-01-01 00:07:28
# 4                  Broadway & Barry Ave  2017-01-01 00:07:57

# %%
# Selecionando as colunas Start Time, End Time, User Type e Gender
df_teste = df_bike.loc[:, ['Start Time', 'End Time','User Type', 'Gender']]
df_teste.head()
# Out:
#             Start Time             End Time   User Type Gender
# 0  2017-01-01 00:00:36  2017-01-01 00:06:32    Customer    NaN
# 1  2017-01-01 00:02:54  2017-01-01 00:08:21  Subscriber   Male
# 2  2017-01-01 00:06:06  2017-01-01 00:18:31  Subscriber   Male
# 3  2017-01-01 00:07:28  2017-01-01 00:12:51  Subscriber   Male
# 4  2017-01-01 00:07:57  2017-01-01 00:20:53  Subscriber   Male

# %%
# Selecionando colunas de Start Time até Gender somente quando Gender for Feminino
df_teste = df_bike.loc[df_bike['Gender'] == 'Female', 'Start Time': 'Gender']
df_teste.head()
# Out:
#              Start Time             End Time  Trip Duration  \
# 10  2017-01-01 00:17:13  2017-01-01 11:03:34          38781
# 14  2017-01-01 00:25:47  2017-01-01 00:39:53            846
# 18  2017-01-01 00:27:28  2017-01-01 00:42:44            916
# 20  2017-01-01 00:27:52  2017-01-01 00:33:46            354
# 22  2017-01-01 00:30:10  2017-01-01 01:10:34           2424
#
#                     Start Station                  End Station   User Type  \
# 10     Wilton Ave & Diversey Pkwy  Halsted St & Wrightwood Ave  Subscriber
# 14  Ravenswood Ave & Lawrence Ave   Clarendon Ave & Gordon Ter  Subscriber
# 18                Millennium Park       Michigan Ave & 18th St  Subscriber
# 20        Paulina Ave & North Ave      Damen Ave & Division St  Subscriber
# 22        Lake Shore Dr & Ohio St         Broadway & Barry Ave  Subscriber
#
#     Gender
# 10  Female
# 14  Female
# 18  Female
# 20  Female
# 22  Female

# %%
# Selecionando todas as colunas quando Trip Duration for maior que 1000
df_teste = df_bike.loc[df_bike['Trip Duration'] > 1000, :]
df_teste.head()
# Out:
#              Start Time             End Time  Trip Duration  \
# 10  2017-01-01 00:17:13  2017-01-01 11:03:34          38781
# 15  2017-01-01 00:25:47  2017-01-01 00:43:23           1056
# 22  2017-01-01 00:30:10  2017-01-01 01:10:34           2424
# 26  2017-01-01 00:35:23  2017-01-01 01:05:22           1799
# 29  2017-01-01 00:35:34  2017-01-01 01:05:26           1792
#
#                  Start Station                  End Station   User Type  \
# 10  Wilton Ave & Diversey Pkwy  Halsted St & Wrightwood Ave  Subscriber
# 15    Clark St & Congress Pkwy        Wolcott Ave & Polk St  Subscriber
# 22     Lake Shore Dr & Ohio St         Broadway & Barry Ave  Subscriber
# 26    McClurg Ct & Illinois St     Fairbanks Ct & Grand Ave    Customer
# 29    McClurg Ct & Illinois St     Fairbanks Ct & Grand Ave    Customer
#
#     Gender  Birth Year
# 10  Female      1988.0
# 15    Male      1984.0
# 22  Female      1985.0
# 26     NaN         NaN
# 29     NaN         NaN

# %%
df_teste = df_bike.loc[df_bike['Start Station'].str.endswith('Illinois St'), :]
df_teste.head()
# Out:
#              Start Time             End Time  Trip Duration  \
# 23  2017-01-01 00:32:58  2017-01-01 00:41:59            541
# 26  2017-01-01 00:35:23  2017-01-01 01:05:22           1799
# 29  2017-01-01 00:35:34  2017-01-01 01:05:26           1792
# 31  2017-01-01 00:37:19  2017-01-01 01:05:22           1683
# 45  2017-01-01 00:56:09  2017-01-01 01:10:51            882
#
#                Start Station               End Station User Type Gender  \
# 23  LaSalle St & Illinois St      State St & Kinzie St  Customer    NaN
# 26  McClurg Ct & Illinois St  Fairbanks Ct & Grand Ave  Customer    NaN
# 29  McClurg Ct & Illinois St  Fairbanks Ct & Grand Ave  Customer    NaN
# 31  McClurg Ct & Illinois St  Fairbanks Ct & Grand Ave  Customer    NaN
# 45  McClurg Ct & Illinois St           Millennium Park  Customer    NaN
#
#     Birth Year
# 23         NaN
# 26         NaN
# 29         NaN
# 31         NaN
# 45         NaN

# %%
df_teste = df_bike.loc[df_bike['Start Time'].apply(lambda x: x[5:7] == '02')]
df_teste.head()
# Out:
#                  Start Time             End Time  Trip Duration  \
# 111942  2017-02-01 00:04:02  2017-02-01 00:13:27            565
# 111943  2017-02-01 00:04:38  2017-02-01 00:10:18            340
# 111944  2017-02-01 00:07:11  2017-02-01 00:11:49            278
# 111945  2017-02-01 00:08:44  2017-02-01 00:13:36            292
# 111946  2017-02-01 00:15:29  2017-02-01 00:25:07            578
#
#                     Start Station                End Station   User Type  \
# 111942  Columbus Dr & Randolph St     Clark St & Chicago Ave  Subscriber
# 111943        Morgan St & Lake St  Milwaukee Ave & Grand Ave  Subscriber
# 111944    Clinton St & Madison St     Clinton St & Tilden St  Subscriber
# 111945   University Ave & 57th St        Ellis Ave & 60th St  Subscriber
# 111946    Hermitage Ave & Polk St   Peoria St & Jackson Blvd  Subscriber
#
#         Gender  Birth Year
# 111942  Female      1991.0
# 111943    Male      1981.0
# 111944    Male      1977.0
# 111945    Male      1976.0
# 111946  Female      1984.0

# %%
test = df_bike['Start Time'].apply(lambda x: x[5:7] == '02')
df_teste2 = df_bike.loc[test, 'Start Time':'Trip Duration']
df_teste2.head()
# Out:
#                  Start Time             End Time  Trip Duration
# 111942  2017-02-01 00:04:02  2017-02-01 00:13:27            565
# 111943  2017-02-01 00:04:38  2017-02-01 00:10:18            340
# 111944  2017-02-01 00:07:11  2017-02-01 00:11:49            278
# 111945  2017-02-01 00:08:44  2017-02-01 00:13:36            292
# 111946  2017-02-01 00:15:29  2017-02-01 00:25:07            578

# %%
df_bike.set_index('User Type', inplace=True)
df_bike.head()
# Out:
#                      Start Time             End Time  Trip Duration  \
# User Type
# Customer    2017-01-01 00:00:36  2017-01-01 00:06:32            356
# Subscriber  2017-01-01 00:02:54  2017-01-01 00:08:21            327
# Subscriber  2017-01-01 00:06:06  2017-01-01 00:18:31            745
# Subscriber  2017-01-01 00:07:28  2017-01-01 00:12:51            323
# Subscriber  2017-01-01 00:07:57  2017-01-01 00:20:53            776
#
#                                    Start Station  \
# User Type
# Customer                    Canal St & Taylor St
# Subscriber            Larrabee St & Menomonee St
# Subscriber  Orleans St & Chestnut St (NEXT Apts)
# Subscriber               Franklin St & Monroe St
# Subscriber                  Broadway & Barry Ave
#
#                              End Station Gender  Birth Year
# User Type
# Customer        Canal St & Monroe St (*)    NaN         NaN
# Subscriber  Sheffield Ave & Kingsbury St   Male      1984.0
# Subscriber    Ashland Ave & Blackhawk St   Male      1985.0
# Subscriber        Clinton St & Tilden St   Male      1990.0
# Subscriber       Sedgwick St & North Ave   Male      1990.0

# %%
df_bike.loc['Customer']
# Out:
#                     Start Time             End Time  Trip Duration  \
# User Type
# Customer   2017-01-01 00:00:36  2017-01-01 00:06:32            356
# Customer   2017-01-01 00:14:57  2017-01-01 00:26:22            685
# Customer   2017-01-01 00:15:03  2017-01-01 00:26:28            685
# Customer   2017-01-01 00:17:01  2017-01-01 00:29:49            768
# Customer    Western Ave & Winnebago Ave      Western Ave & Winnebago Ave
# Customer    Western Ave & Winnebago Ave      Western Ave & Winnebago Ave
# Customer              Clark St & Elm St           Clark St & Randolph St
# Customer   Sheridan Rd & Irving Park Rd                  Montrose Harbor
# Customer              Clark St & Elm St           Clark St & Randolph St
# Customer   Sheridan Rd & Irving Park Rd                  Montrose Harbor
# Customer              Clark St & Elm St           Clark St & Randolph St
# Customer              Clark St & Elm St           Clark St & Randolph St
# Customer           State St & Kinzie St       Lake Shore Dr & North Blvd
# Customer        Streeter Dr & Grand Ave       Indiana Ave & Roosevelt Rd
# Customer         State St & Randolph St         Canal St & Monroe St (*)
# Customer    Field Blvd & South Water St                   Dusable Harbor
# Customer           State St & Kinzie St       Lake Shore Dr & North Blvd
# Customer         State St & Randolph St         Canal St & Monroe St (*)
# Customer         State St & Randolph St         Canal St & Monroe St (*)
# Customer       Wells St & Evergreen Ave        Milwaukee Ave & Grand Ave
# Customer         State St & Randolph St         Canal St & Monroe St (*)
# Customer        Cuyler Ave & Augusta St     Central Park Ave & North Ave
# Customer        Cuyler Ave & Augusta St     Central Park Ave & North Ave
# Customer                 Dusable Harbor          Streeter Dr & Grand Ave
# Customer                 Dusable Harbor          Streeter Dr & Grand Ave
#
#           Gender  Birth Year
# User Type
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# ...          ...         ...
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
# Customer     NaN         NaN
#
# [317162 rows x 7 columns]

# %%
# Resetando index

df_bike = df_bike.reset_index(drop=True)
df_bike.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-01-01 00:00:36  2017-01-01 00:06:32            356
# 1  2017-01-01 00:02:54  2017-01-01 00:08:21            327
# 2  2017-01-01 00:06:06  2017-01-01 00:18:31            745
# 3  2017-01-01 00:07:28  2017-01-01 00:12:51            323
# 4  2017-01-01 00:07:57  2017-01-01 00:20:53            776
#
#                           Start Station                   End Station Gender  \
# 0                  Canal St & Taylor St      Canal St & Monroe St (*)    NaN
# 1            Larrabee St & Menomonee St  Sheffield Ave & Kingsbury St   Male
# 2  Orleans St & Chestnut St (NEXT Apts)    Ashland Ave & Blackhawk St   Male
# 3               Franklin St & Monroe St        Clinton St & Tilden St   Male
# 4                  Broadway & Barry Ave       Sedgwick St & North Ave   Male
#
#    Birth Year
# 0         NaN
# 1      1984.0
# 2      1985.0
# 3      1990.0
# 4      1990.0

# %% [markdown]
# ## .iloc
# Indexando através do índice (num) da coluna do Dataset.

# %%
for i, v in enumerate(df_bike.columns):
    print(i, v)
# Out:
# 0 Start Time
# 1 End Time
# 2 Trip Duration
# 3 Start Station
# 4 End Station
# 5 Gender
# 6 Birth Year

# %%
# Seleciona as duas primeiras colunas do Dataset
df_teste = df_bike.iloc[:, :2]
df_teste.head()
# Out:
#             Start Time             End Time
# 0  2017-01-01 00:00:36  2017-01-01 00:06:32
# 1  2017-01-01 00:02:54  2017-01-01 00:08:21
# 2  2017-01-01 00:06:06  2017-01-01 00:18:31
# 3  2017-01-01 00:07:28  2017-01-01 00:12:51
# 4  2017-01-01 00:07:57  2017-01-01 00:20:53

# %%
# Seleciona apenas as duas primeiras colunas das três primeiras linhas
df_teste = df_bike.iloc[:3, :2]
df_teste.head()
# Out:
#             Start Time             End Time
# 0  2017-01-01 00:00:36  2017-01-01 00:06:32
# 1  2017-01-01 00:02:54  2017-01-01 00:08:21
# 2  2017-01-01 00:06:06  2017-01-01 00:18:31

# %%
df_teste = df_bike.iloc[:, 5]
df_teste.head()
# Out:
# 0     NaN
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# Name: Gender, dtype: object
